# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
datos = pd.read_csv("C:/Users/fredy/OneDrive/Desktop/framingham.csv", sep=",")

# %%
datos
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
datos[['BMI','TenYearCHD']].head()
# Out:
#      BMI  TenYearCHD
# 0  26.97           0
# 1  28.73           0
# 2  25.34           0
# 3  28.58           1
# 4  23.10           0

# %%
datos[['BMI','TenYearCHD']].plot.scatter(x='BMI',y='TenYearCHD')
# Out:
# <Axes: xlabel='BMI', ylabel='TenYearCHD'>

# %%
w = 0.09
b = -3.6

# %%
x = np.linspace(0,datos['BMI'].max(),100)
y = 1/(1+np.exp(-(w*x+b)))

# %%
datos.plot.scatter(x='BMI',y='TenYearCHD')
plt.plot(x, y, color='black')
plt.ylim(0,datos['TenYearCHD'].max()*1.1)
plt.scatter(x, y, color='red')
plt.grid()
plt.xlabel('Indice de Masa Corporal')
plt.ylabel('Pronostico Enfermedad Coronaria 1:Positivo 0:Negativo')
plt.show()
